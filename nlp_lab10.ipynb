# %%
# ==========================================
# TF-IDF + K-MEANS CLUSTERING
# ==========================================

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# ------------------------------------------
# Get posts from user
# ------------------------------------------

posts = []

n = int(input("Enter number of posts: "))

for i in range(n):
    post = input("Enter post: ")
    posts.append(post)

# ------------------------------------------
# Get number of clusters
# ------------------------------------------

k = int(input("Enter number of clusters: "))

# ------------------------------------------
# TF-IDF Vectorization
# ------------------------------------------

vectorizer = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1, 2)
)

X = vectorizer.fit_transform(posts)

# ------------------------------------------
# K-Means Clustering
# ------------------------------------------

model = KMeans(
    n_clusters=k,
    random_state=42,
    n_init=10
)

model.fit(X)

# Get cluster labels
labels = model.labels_

# ------------------------------------------
# Display Cluster Results
# ------------------------------------------

print("\nCluster Results:\n")

for i in range(len(posts)):
    print("Post:", posts[i])
    print("Cluster:", labels[i])
    print()

# ------------------------------------------
# Important Keywords in Each Cluster
# ------------------------------------------

terms = vectorizer.get_feature_names_out()

print("Important Keywords:\n")

for i in range(k):

    center = model.cluster_centers_[i]

    # Get top 5 keywords
    top = center.argsort()[-5:][::-1]

    print("Cluster", i)

    for j in top:
        print(terms[j])

    print()

# ------------------------------------------
# Marketing Insight
# ------------------------------------------

print("Marketing Insight:")
print("Similar customer opinions are grouped together.")
print("Clusters help identify product trends and issues.")
# Out:
# Enter number of posts: 3
# Enter post: This phone has excellent camera quality
# Enter post: The camera is very good and battery lasts long
# Enter post: The laptop performance is excellent
# Enter number of clusters: 2
#
# Cluster Results:
#
# Post: This phone has excellent camera quality
# Cluster: 1
#
# Post: The camera is very good and battery lasts long
# Cluster: 0
#
# Post: The laptop performance is excellent
# Cluster: 1
#
# Important Keywords:
#
# Cluster 0
# good battery
# long
# lasts long
# camera good
# battery lasts
#
# Cluster 1
# excellent
# performance excellent
# laptop
# laptop performance
# performance
#
# Marketing Insight:
# Similar customer opinions are grouped together.
# Clusters help identify product trends and issues.
